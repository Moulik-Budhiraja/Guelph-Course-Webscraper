# %%
import json
import re
import pandas as pd
from enum import Enum

# %%
with open("courses.json", "r") as f: 
    data = json.load(f)

df = pd.DataFrame.from_records(data)

# %% [markdown]
# ### Substitutions

# %%
parsed = []

useless_phrases = ["is strongly recommended", "is recommended", "Take", r"Prerequisite\(s\): "]

for text in df["prerequisites"].to_list():
    # Remove courses
    # temp = re.sub(r"\w{2,4}\*[0-9]{4}", "___", text)
    temp = text

    # Remove useless phrases
    temp = re.sub(r"|".join(useless_phrases), "", temp)

    parsed.append(temp)

print(len(set(parsed)))

set(parsed)
# Out:
# 1124
# {'',
#  '(CIS*3750 or CIS*3760), (CIS*2460 or STAT*2040)',
#  '10.00 credits including ONEH*2000',
#  '12.50 credits including (1 of ANTH*2160, ANTH*2180, IDEV*2300, SOC*2080), (1 of IDEV*2100, SOAN*2120, WMST*3000)',
#  'SART*2700',
#  'THST*2050, THST*2190 and 2.00 credits at the 3000-level in Theatre Studies',
#  'MCB*2050, PSYC*3270, (1 of NEUR*2000, NEUR*2100, PSYC*2410), (1 of BIOM*3200, HK*2810, ZOO*3600)',
#  '15.00 credits including (STAT*2040 or STAT*2230), ZOO*2090',
#  'SART*2200',
#  'A minimum grade of 70% in MUSC*2410.',
#  'CRWR*3100',
#  'ENGG*1210, ENGG*1500, 0.50 credits in calculus',
#  'HK*4371',
#  'GERM*1100',
#  '1 of ANTH*1150, IDEV*1000, SOC*1100',
#  'BIOC*2580, ZOO*2090, (STAT*2040 or STAT*2230 )',
#  'LARC*2230',
#  'FRHD*2040',
#  '9.00 credits including (2 of BIOL*1070, BIOL*1080, BIOL*1090)',
#  'CTS*2000, CTS*2010, and CTS*3000',
#  '(CIS*2030 or ENGG*3640), CIS*3110',
#  'IES*1020',
#  'ECON*3740',
#  'FRHD*3400, NUTR*2050',
#  'MCB*3010',
#  '4.00 credits including (JLS*1000 or POLS*1150)',
#  '10.00 credits including GEOG*2420',
#  'HK*3501',
#  '14.00 credits, including 1.00 credits in Political Science at the 3000 level.',
#  'ECON*1050 or FARE*1040',
#  '15.00 credits including list of required Entrepreneurship Minor courses.',
#  'IDEV*2200 or (ECON*1050, ECON*1100)',
#  'MCS*1000, (1 of BUS*2090, HROB*2090, HROB*2100, PSYC*1000, PSYC*1200). Although not required, it  that students take PSYC*1000 prior to MCS*2600.',
#  '(BIOM*2000 or BIOM*3200), FRHD*3070, NUTR*2050, (NUTR*3190 or NUTR*3210), STAT*2090',
#  'CHEM*4900',
#  'ECON*3740, ECON*3810',
#  '(1 of MATH*1080, MATH*1200), (4U Physics or equivalent )',
#  '1.00 credits from the following: (HISP*3220 or SPAN*3220), (HISP*3230 or SPAN*3230), SPAN*3080',
#  'BIOC*3560, MBG*2040, MICR*2430',
#  'PHIL*2110',
#  'SART*3770',
#  'MBG*2040, (STAT*2040 or STAT*2230)',
#  '4.00 credits completed; minimum 60% cumulative average',
#  'SART*3300',
#  'CHEM*2070, (1 of CHEM*3430, CHEM*3640, CHEM*3650, NANO*3200, NANO*3300, NANO*3500, TOX*3300, TOX*3360)',
#  '7.00 credits in CIS',
#  '(ENGG*2230 or MET*2030), (MATH*1210 or MATH*2080), (STAT*2120 or STAT*2040), and competency in computing.',
#  '9.50 credits',
#  'ITAL*1070',
#  '6.00 credits of ENGG courses, ENGG*2230, MATH*2130, (ENGG*2450 or PHYS*1010)',
#  '1 of ANTH*2160, ANTH*2180, IDEV*2500, SOAN*2112',
#  'Completion of previous co-op work requirements in COOP*2000',
#  '(2 of POLS*2150, POLS*2230, POLS*2250, POLS*2300, POLS*2350, POLS*3250) and 1.00 credits in the Public Policy, Governance and Law or Canadian Politics stream. Streams are defined under the Political Science Major.',
#  'COOP*1100',
#  'CLAS*1000 or CLAS*2000',
#  'LAT*2000',
#  '8.00 credits including (1 of ANTH*1150, FRHD*1010, FRHD*1020, FRHD*1100, PSYC*1000, SOC*1100)',
#  '7.50 credits including 0.50 credits in History, (1 of 0.50 credits in History, PHIL*2060, POLS*2150, SOAN*2400, WMST*1000, WMST*2000)',
#  'PHYS*2340, PHYS*3130',
#  '7.50 credits, including MUSC*1160, MUSC*1340',
#  '14.50 credits including ECON*2310, (BUS*3320 or MGMT*3320), (ECON*2560 or FIN*2000)',
#  'ENGG*2230, ENGG*3260',
#  'GERM*2010 or 2.50 credits in German',
#  '19.75 credits towards the BENG BME major, all 1000 and 2000 level core courses, ENGG*4000.',
#  '10.00 credits including 1.50 credits in ITAL',
#  'ENGG*3260',
#  '10.00 credits including (ECON*3740 or MCS*3030)',
#  'NUTR*4810',
#  '(4U Physics or PHYS*1020), 4U Mathematics',
#  'ECON*2310, (ECON*2770 or MATH*1210)',
#  '7.50 credits including HIST*1010',
#  'NANO*3300, NANO*3500, (CHEM*3860 or PHYS*3230)',
#  '15.00 credits including ACCT*3340',
#  'GEOG*1220 or IDEV*1000',
#  'THST*3500',
#  'CIS*2750, CIS*3250, CIS*3760',
#  'PHYS*4040',
#  '(1 of CROP*3300, CROP*3310, CROP*3340), (1 of AGR*2320, ENVS*3080, ENVS*4090, ENVS*4160)',
#  'BIOL*2060, BIOL*2400',
#  '1.00 credits in Philosophy at the 3000 level or PHIL*2070',
#  '1 of POLS*1500, POLS*2100, POLS*2200',
#  'FOOD*2100, FOOD*3700, (FOOD*3030 or FOOD*3050), (FOOD*3140 or FOOD*3160), (FOOD*3230 or FOOD*3240)',
#  'SART*2300',
#  'MUSC*2710',
#  '12.50 credits including (1 of ANTH*2160, ANTH*2180, SOAN*2112, SOC*2700), SOAN*2120',
#  '(1 of 4U Physics, PHYS*1020, PHYS*1300 ), 4U Mathematics',
#  'HK*2270',
#  'FREN*1200 or equivalent, such as grade 12 French Immersion',
#  '1 of ANTH*2160, ANTH*2180, IDEV*2010, IDEV*2300, IDEV*2500, SOC*2080',
#  '7.50 credits including 0.50 credits in English (excluding ENGL*1030)',
#  'SPAN*2000',
#  '70% average in all POLS courses. Recommendation: Students with less than a 75% average are advised not to take this course.',
#  '14.00 credits including IDEV*3000, IDEV*3100',
#  '10.00 credits including 1.50 credits in European Studies.',
#  '(1 of IPS*1510, MATH*1090, MATH*1210, MATH*2080), (STAT*2040 or STAT*2120)',
#  '1 of POLS*1400, POLS*2230, POLS*2250',
#  '4.00 credits including (1 of FRHD*1010, FRHD*2060, FRHD*2270, FRHD*2280, PSYC*2450)',
#  '(1 of IDEV*2000, POLS*2080 or POLS*2100) and 1.00 credits at the 3000 level in the Comparative Politics stream. Streams are defined under the Political Science Major.',
#  '10.00 credits including 2.00 credits in Art History.',
#  '(1 of CIS*1300, CIS*1500, ENGG*1410), (1 of IPS*1510, MATH*1090, MATH*1210, MATH*2080)',
#  'PSYC*1000, (PSYC*1010 or STAT*2040)',
#  '1 of CROP*3300, CROP*3310, ENVB*2040, ENVB*3090, ENVS*2040, ENVS*3090, HORT*3280, HORT*3350, HORT*3510',
#  'CHEM*1040, (MATH*1090 or MATH*1210)',
#  '19.75 credits towards the BENG MECH major, all 1000 and 2000 level core courses, ENGG*4000.',
#  '10.00 credits including (ACCT*2230 or MCS*2600)',
#  'MUSC*3550',
#  '7.50 credits including (MUSC*2670 or MUSC*3010), MUSC*3630',
#  'GREK*2020',
#  '1 of ECON*2740, GEOG*2460, STAT*2040, STAT*2060, STAT*2230',
#  'HK*3401',
#  '(ENVS*2080 or ENVS*2320 or [MBG*2040, (BIOL*2060 or MICR*2420)]',
#  'CRWR*2000',
#  'MATH*2130, MATH*2270, (1 of CIS*1300, CIS*1500, ENGG*1410)',
#  'EQN*2150',
#  '10.00 credits, including 1.50 credits in History at the 3000-level',
#  'CLAS*3060 or CLAS*3120',
#  'IPS*1510 or [(MATH*1210 or MATH*2080), (1 of PHYS*1010, PHYS*1070, PHYS*1130)]',
#  'GEOG*1220 ',
#  'PHYS*4040, PHYS*4240',
#  '(PHYS*2340 or PHYS*2470)',
#  '9.00 credits, (HTM*2020 or SPMT*2020)',
#  '(BIOL*1050 or BIOL*1070), BIOL*1090',
#  '1.50 credits in NANO courses at the 3000 level.',
#  'ENGG*2450',
#  'PSYC*2070, PSYC*2360, (3 of PSYC*2020, PSYC*2310, PSYC*2330, PSYC*2390, PSYC*2410, PSYC*2450, PSYC*2650, PSYC*2740)',
#  'NEUR*2000 or 2.50 credits in Psychology',
#  '2.00 credits or CTS*1000',
#  '15.00 credits including MCS*2600',
#  '8.00 credits including (1 of FRHD*1010, FRHD*2060, FRHD*2260, FRHD*2270, FRHD*2280, PSYC*2450)',
#  'BOT*2100 or MICR*2430',
#  'POLS*2000 or POLS*3280',
#  '4.00 credits including BIOL*1070',
#  'SOC*1100 or SOC*1500',
#  '(ACCT*1220 or ACCT*2220), (1 of ECON*2740, PSYC*1010, STAT*2040, STAT*2060, STAT*2080, STAT*2120)',
#  'NUTR*3210, (BIOM*3200 or HK*3810)',
#  '4U Chemistry (or equivalent) or CHEM*1060',
#  '12.50 credits including SOC*3310, SOAN*3070, SOAN*3120',
#  '(2 of POLS*2230, POLS*2250, POLS*2300), 1.00 credits in the Public Policy, Governance and Law stream or the Canadian Politics stream. Streams are defined under the Political Science Major.',
#  '10.00 credits including BIOL*2060, (1 of GEOG*2460, STAT*2040, STAT*2060, STAT*2230)',
#  'ENGG*1210',
#  'ENGL*1080, (1 of ENGL*2120, ENGL*2130, ENGL*2920)',
#  '2.50 credits in Psychology including PSYC*2310',
#  'REAL*1820, (ACCT*2230 or REAL*2820)',
#  'MUSC*1170 or MUSC*2180',
#  'ENGG*3390, ENGG*3410',
#  '1.50 credits in Classical Studies courses at the 3000 level',
#  'Completion of the music core.',
#  'MGMT*3140, MGMT*3200',
#  '12.00 credits, including (1 of ASCI*3000, ASCI*3100, ASCI*3200, ASCI*3700); cumulative average of 75%',
#  '1 of CIS*1200, CIS*1300, CIS*1500',
#  '10.00 credits including (HIST*2100 or HIST*2600)',
#  'STAT*2080',
#  'CIS*3110',
#  'CHEM*1050, MATH*2270',
#  'STAT*2040 or STAT*2120',
#  '10.00 credits including, (EURO*1100 or EURO*1200), EURO*2200, EURO*3000, EURO*3300',
#  'MATH*1160, MATH*2000',
#  '2.50 credits in Psychology including PSYC*2650',
#  'BIOL*2060, BIOL*3450, PHYS*1080',
#  '1 of THST*3150, THST*3160, THST*3170, THST*4270',
#  '12.00 credits including FRHD*1020',
#  '(AGR*1110 or AGR*1250) or registration in International Development',
#  '(MATH*2170 or MATH*2270), (PHYS*2310 or PHYS*2440)',
#  'STAT*2040 or STAT*2230',
#  'CIS*2750, CIS*3110, (CIS*2460 or STAT*2040)',
#  'MUSC*2720',
#  '9.00 credits including (1 of MATH*1030, MATH*1080, MATH*1200) (1 of ECON*2740, PSYC*1010, STAT*2040, STAT*2060)',
#  '1 of ENGG*2010, ENGG*2560, ENGG*2660',
#  'SXGN*3000, SXGN*3010',
#  'SART*2710',
#  'MBG*2040, MCB*2050, (1 of BIOM*3040, BIOM*4070, ZOO*3000)',
#  'BIOL*3450',
#  'CHEM*2060',
#  'CLAS*3030 or CLAS*3040',
#  'ENVS*2030',
#  'BLCK*1000 or BLCK*2000',
#  '[1 of or ECON*3610, ECON*3810, (ECON*3860 or FIN*3400)], (ECON*3710 or ECON*3620)',
#  'MBG*2040 or MBG*2400',
#  'Minimum of 4.00 credits',
#  '(1 of IPS*1510, MATH*1210, MATH*2080), (IPS*1500 or PHYS*1080)',
#  'MBG*3040',
#  'BIOL*1050 or BIOL*1070',
#  '1 of BOT*2100, ENVB*2030, ENVS*2040, ENVS*2330',
#  '7.50 credits including (HIST*2000 or HIST*2200)',
#  '7.50 credits including 1.50 History credits',
#  '14.00 credits including (PSYC*3290 or STAT*2050)',
#  'SOC*4900',
#  '10.00 credits including IDEV*2010 or IDEV*2500',
#  'BLCK*2020',
#  '7.50 credits, including (GEOG*2000 or GEOG*2110), (1 of GEOG*2460, STAT*2040, STAT*2230)',
#  'IPS*1500 or [ PHYS*1080, (1 of MATH*1000, MATH*1080, MATH*1200)], (1 of IPS*1510, PHYS*1010, PHYS*1070, PHYS*1130)',
#  'THST*1040',
#  'LARC*2410',
#  '2.50 credits in Theatre Studies including THST*3190',
#  'AGR*4450',
#  'ENGG*2400, STAT*2120, (1 of CIS*1300, CIS*1500, ENGG*1410)',
#  '7.50 credits including MUSC*2140',
#  'ENGL*1080, ENGL*2920',
#  'ENGG*2410, ENGG*2450',
#  '12.50 credits.',
#  'BIOL*1050 or BOT*2100',
#  '1 of IDEV*2400, POLS*2100, POLS*2350',
#  'STAT*3110, STAT*3240',
#  'ASCI*1110',
#  '13.00 credits including FRHD*2100',
#  '14.50 credits including NUTR*3090, (BIOM*2000 or BIOM*3200)',
#  'THST*1190',
#  '1.50 credits at the 3000 level in Political Science or equivalent',
#  'MUSC*1720',
#  '1 of BIOL*1040, BIOL*1050, BIOL*1070',
#  '4.00 credits including (1 OF ANTH*1150, FRHD*1010, FRHD*1020, FRHD*1100, PSYC*1000, SOC*1100)',
#  'TOX*2000, (CHEM*3430, TOX*3300)',
#  'ENGG*2400, MATH*2270, (1 of BIOL*1070, BIOL*1080, BIOL*1090)',
#  '(1 of IPS*1510, MATH*1090, MATH*1210, MATH*2080), (1 of STAT*2050, STAT*3240, STAT*3100)',
#  'CIS*2030, CIS*2750, CIS*3110',
#  'MBG*2040',
#  '1 of ANSC*2340, BIOL*2060, BIOL*2400, ZOO*2090',
#  'ENGG*1210, ENGG*1500, MATH*1200, MATH*1210, PHYS*1010',
#  'ANTH*2660 or HIST*2090',
#  '1 of FREN*1150, Grade 12U French or permission of the School of Languages and Literatures',
#  'CRWR*2300',
#  'POLS*4970',
#  'BIOL*1070, CHEM*1040',
#  '(FOOD*2150 or HTM*2700), (1 of STAT*2040, STAT*2060, STAT*2080)',
#  'BIOM*3090',
#  'MATH*1080 or MATH*1200',
#  '(1 of BIOC*3570, CHEM*3430, TOX*3300), BIOC*3560, (MBG*2020 or MBG*2040)',
#  'BIOC*2580, MCB*2050',
#  'ECON*2310, ECON*2410',
#  'ECON*3710',
#  'MUSC*2660, (MUSC*2330 or MUSC*2620)',
#  'ECON*3740, (ECON*3710 or ECON*3520)',
#  'PSYC*3270, (NEUR*2000 or PSYC*2410)',
#  'JLS*4800',
#  'FRHD*3070, STAT*2090',
#  'MUSC*2910',
#  '1 of BIOL*2060, BOT*3050, ENVS*2330',
#  'CHEM*1040, (1 of BIOL*1070, BIOL*1080, MICR*2420)',
#  '12.50 credits including (IDEV*2100 or SOAN*2120), (1 of ANTH*2160, ANTH*2180, IDEV*2300, SOAN*2112, SOC*2080)',
#  '15.00 credits including REAL*3810, REAL*4820',
#  '5.00 credits in chemistry including (1.50 credits from CHEM*3430, CHEM*3640, CHEM*3650, CHEM*3750, CHEM*3760, CHEM*3870)',
#  'MATH*2200',
#  'NEUR*4421',
#  'IPS*1500 or [(1 of PHYS*1010, PHYS*1070, PHYS*1080, PHYS*1130, PHYS*1300), (1 of MATH*1030, MATH*1080, MATH*1160, MATH*1200)]',
#  'UNIV*1250, UNIV*1260',
#  'UNIV*1250',
#  '(HTM*2020 or SPMT*2020), (ECON*2560 or FIN*2000)',
#  'BIOL*1090, (BIOL*1070 or BIOL*1080)',
#  '13.00 credits, (1 of FRHD*2040, FRHD*2300, FRHD*2350, FRHD*2400, POLS*2230)',
#  'HK*2810',
#  '(ENGG*1500 or MATH*1160), (1 of IPS*1510, MATH*1090, MATH*1210, MATH*2080)',
#  'POLS*2200 and 1.00 credit at the 3000 level in the Comparative Politics and/or International Relations and Global Studies streams. Streams are defined under the Political Science Major.',
#  '7.50 credits including (1.00 credits in IDEV courses at the 2000 level or ONEH*2000)',
#  '(2 of POLS*2150, POLS*2230, POLS*2250, POLS*2300, POLS*2350), and 1.00 credits in the Public Policy, Governance and Law or Canadian Politics streams. Streams are defined under the Political Science Major.',
#  'BIOL*1090, BIOC*2580',
#  'ENGG*2410, ENGG*2450, ENGG*3450',
#  'HROB*2010, HROB*3100, MGMT*3300',
#  'ACCT*3350 or BUS*3350',
#  '10.00 credits including HIST*2500.',
#  'CHEM*1050, (1 of ENVS*1050, ENVS*2060, ENVS*2240)',
#  '10.00 credits including 1.50 credits in French Studies.',
#  'ANSC*3080, ANSC*3120, MBG*3060',
#  'FRHD*2300 or FRHD*2400',
#  '3.00 credits in Studio Art',
#  '(BIOC*2580 or CHEM*2880), (1 of MATH*1030, MATH*1080, MATH*1200)',
#  '2.50 credits in Theatre Studies including THST*3140 or 1.00 credits in English',
#  '1 of FARE*2410, BUS*3320, ECON*2770, MGMT*3320',
#  '(BIOL*1080 or BIOL*1090), STAT*2040',
#  'TOX*4900',
#  'BIOC*2580, CHEM*3650',
#  '1 of (1.00 credits in Philosophy at the 3000 level, 12.50 credits, PHIL*3190)',
#  'ECON*2310',
#  'AGR*2470, STAT*2040, (BIOL*1050 or BIOL*1070)',
#  'GEOG*2030 or IDEV*2400',
#  '(ENVB*3090 or ENVS*3090) or (ENVB*4040 or ENVS*4040)',
#  'GEOG*2420 or GEOG*2480',
#  'CHEM*3640',
#  '15.00 credits including (1 of BUS*3000, HROB*2100, HROB*2290, HROB*3000, PSYC*3070)',
#  'LARC*3070, LARC*4510',
#  'Completion of the music core, a minimum grade of 70% in MUSC*3510',
#  'ANSC*3080',
#  'CIS*2750, MATH*1160, STAT*2040',
#  'PHYS*3230',
#  'HROB*2010, (1 of PHIL*2120, PHIL*2600, POLS*3440), (2 of BUS*3000, EDRD*3140, EDRD*3160, EDRD*4120, HROB*2090, HROB*2290, HROB*3000, MGMT*2150, PHIL*2100, POLS*2250) plus 120 hours of leadership experience.',
#  '14.50 credits including NUTR*2050, NUTR*3210',
#  '(CHEM*2820 or PHYS*3240), CHEM*3860',
#  'ENVS*3200 or ENVS*3310',
#  'ANSC*3080 or (EQN*2040, EQN*2050)',
#  'ENGG*2660 or (HK*2270, HK*3600)',
#  '3.00 credits in Theatre Studies including THST*3140, THST*2190, (1 of THST*2050, THST*2120)',
#  '13.00 credits including (1 of FRHD*1010, FRHD*2060, FRHD*2270, FRHD*2280, PSYC*2450)',
#  '4.00 ENGG credits, including ENGG*1210',
#  '7.50 credits including BIOL*1070',
#  'FRHD*3200 or FRHD*3250',
#  'ENGG*2230, ENGG*3650, ENGG*3670',
#  'ENGG*3450',
#  '7.50 credits including 1.00 credit in IDEV courses at the 2000 level',
#  '1 of IPS*1500, MATH*1080, MATH*1160, MATH*1200',
#  '1.00 credits in Mathematics at the 3000 level or above.',
#  '1.00 credits in Philosophy at the 3000 level or 12.50 credits',
#  '14.00 credits including BIOL*1080, STAT*2040',
#  'CHIN*1200',
#  'ENGG*3080, ENGG*3370, ENGG*3430',
#  '10.00 credits',
#  '1 of EDRD*3400, OAGR*2070, SOC*2080',
#  '1 of PSYC*1000, PSYC*1100, PSYC*1200',
#  'SXGN*2000, SXGN*2010',
#  'BIOL*1040 or (2 of BIOL*1050, BIOL*1070, BIOL*1080, BIOL*1090)',
#  'POLS*2300 and 1.00 credits at the 3000 level in the Canadian Politics stream. Streams are defined under the Political Science Major.',
#  '1 of NEUR*2000, PSYC*2390, PSYC*2410, PSYC*2650',
#  'CRWR*2400 or THST*2120',
#  'BIOM*4521',
#  '1 of 2.00 credits,ARTH*1510, ARTH*1520',
#  '(SOAN*2112 or SOC*2700), (POLS*2650 or SOAN*2120)',
#  '1 of 4U Calculus and Vectors, Advanced Functions and Calculus, OAC Calculus, MATH*1080',
#  'SART*2460 or SART*2610',
#  'FRHD*3070, NUTR*2050',
#  'ASCI*1120',
#  'MCS*1000, (HTM*2020 or SPMT*2020)',
#  '(MBG*2040 or MBG*2400), STAT*2040',
#  '10.00 credits including 1.50 credits at the 3000-level in HIST or ASCI',
#  '0.50 credits in Mathematics at the 3000 level.',
#  '1 of BOT*2100, MICR*2030, (BIOL*1070, BIOL*1090, MBG*2040)',
#  '1 of BIOM*3200, HK*2810, ZOO*3210, ZOO*3600',
#  'CHEM*3750',
#  'CRWR*3400 or CRWR*3500',
#  '5.00 credits, (1 of BIOL*1040, BIOL*1050, BIOL*1070)',
#  'ECON*1050, (1 of IPS*1500, MATH*1030, MATH*1080, MATH*1200), (1 of ECON*2740, PSYC*1010, PSYC*2010, SOAN*2120, STAT*2040, STAT*2060, STAT*2080, STAT*2120)',
#  '9.00 credits including CIS*2520, (CIS*2430 or ENGG*1420)',
#  '10.00 credits including (FARE*2410 or FARE*2700)',
#  '1 of HTM*1070, HTM*2020, HTM*2170',
#  'A minimum grade of 70% in MUSC*2500',
#  '1 of (1.50 credits in Philosophy, 7.50 credits, PHIL*2180)',
#  '1.00 credits in Philosophy at the 3000 level',
#  'ANSC*3120',
#  'MATH*2130, STAT*2120',
#  '1.00 credits in Philosophy at the 3000-level',
#  'BIOL*2400, ZOO*2090',
#  'Minimum of 12.00 credits',
#  'IES*1010',
#  'ASCI*4700',
#  'SOC*1500',
#  '14.00 credits including SOAN*3070, SOAN*3120, SOC*3310',
#  'SART*3090',
#  'CIS*2750, CIS*3750',
#  'CHEM*1040',
#  'ECON*2410, (ECON*2740 or STAT*2040), (ECON*2770 or MATH*1210)',
#  '(1 of FARE*2700, ECON*2310, ECON*2100), 0.50 credits at the 3000 or 4000 level in FARE or ECON',
#  'ENGG*2230, (1 of ENGG*2010, ENGG*2560, ENGG*2660)',
#  'MGMT*3320, [1 of ( ECON*2560 or FIN*2000), ECON*3460, ECON*3560], (1 of FARE*3310, HTM*3120, REAL*3890)',
#  '(ACCT*1220 or ACCT*2220), (1 of ECON*2740, PSYC*1010, STAT*2040, STAT*2060, STAT*2080)',
#  'HK*4441',
#  '1 of ANTH*1150, FRHD*1010, PHIL*1010, POLS*1400, PSYC*1000, PSYC*1100, PSYC*1200, SOC*1100, SOC*1500',
#  '7.50 credits, including THST*2050, THST*2190',
#  '14.00 credits including HTM*3160',
#  '19.75 credits towards the BENG ENVE major, all 1000 and 2000 level core courses, ENGG*4000.',
#  'ENGG*3380',
#  'CIS*2520',
#  'HK*3600',
#  '2.00 credits in Psychology, (1 of BIOM*3090, NEUR*2000, PSYC*2410)',
#  'ENGG*3160 or (ENGG*3010, ENGG*4010)',
#  '14.00 credits, minimum 70% cumulative average',
#  '9.00 credits including HROB*2010, (HROB*2090 or HROB*2100)',
#  'CHEM*1050',
#  '1 of BIOM*3200, HK*3810, HK*3940',
#  'HISP*2990 or SPAN*2990',
#  '1 of ANTH*1150, IDEV*1000, IES*1010, SOC*1100',
#  '10.00 credits including HIST*2450, and at least 1.00 credits in History at the 3000 level or above.',
#  '1 of SPAN*3210, SPAN*3220, SPAN*3230',
#  '7.50 credits, including THST*2270',
#  'CIS*2030, CIS*3110, CIS*3150',
#  'CTS*1000, (CTS*2000 or CTS*2010)',
#  'ECON*2310, (1 of ECON*2740, PSYC*2010, STAT*2040, STAT*2050, STAT*2060, STAT*2080, STAT*2090, STAT*2100, STAT*2120)',
#  '1 of IPS*1500, MATH*1080, MATH*1200',
#  'LAT*1100 or Grade 12 Latin',
#  'SART*2090',
#  '7.50 credits, including MUSC*2100',
#  'LING*1000',
#  '10.00 credits including ( 1 of ECON*2740, PSYC*1010, STAT*2040, STAT*2060, STAT*2080)',
#  'MICR*3230',
#  'GEOG*3210',
#  'MGMT*4020, minimum 70% cumulative average',
#  'A minimum grade of 70% in MUSC*1500.',
#  'BIOL*1070, BIOL*1090',
#  '4U Chemistry or 4U Physics',
#  '7.50 credits including (1 of HIST*2500, HIST*2510, HIST*2800, HIST*2930)',
#  'MATH*1160, 0.50 credits in statistics',
#  'BIOC*2580, (1 of BIOL*1050, BIOL*1070, BIOL*1080), (1 of AGR*2470, FOOD*2150, FOOD*3090, NUTR*3210)',
#  '(1 of BIOM*3200, HK*3810, HK*3940), (1 of BIOM*3010, HK*3401, HK*3501, ZOO*2090)',
#  'GEOG*1300 or GEOG*1350',
#  '12.50 credits including AGR*2470',
#  'ENGG*2180, ENGG*3070',
#  'IES*4000',
#  'POLS*2230 or POLS*2250',
#  'CIS*2500, STAT*2040',
#  '0.50 credits in Ecology',
#  '14.00 credits including (2 of SOC*3490, SOC*3710, SOC*3730, SOC*3740, SOC*3750), (1 of ANTH*3690, SOC*2700, SOC*3310), (SOAN*3120 or POLS*3650)',
#  '(1 of IDEV*2000, IDEV*2400, POLS*2080, POLS*2100, POLS*2200), 1.00 credits at the 3000 level in Political Science.',
#  '(4U Calculus and Vectors or equivalent), (4U Physics or equivalent)',
#  'EQN*2050 or NUTR*3210',
#  'BIOC*2580, BIOL*1080',
#  'ANSC*2340 or ANSC*3080',
#  'IBIO*3100',
#  '19.75 credits towards the BENG CENG major, all 1000 and 2000 level core courses, ENGG*4000.',
#  'MATH*2000, (MATH*1160 or MATH*2160)',
#  'A minimum grade of 70% in MUSC*2420 and (2 of MUSC*2530, MUSC*2540, MUSC*2550, MUSC*2560).',
#  'GEOG*1200 or (ANTH*1150 and GEOG*1220)',
#  '1 of BIOL*1050, BIOL*1070, BIOL*1080, BIOL*1090',
#  'SART*4090',
#  '1.50 credits in Philosophy or 7.50 credits or PHIL*2120',
#  'ITAL*3060',
#  '(MBG*2040 or MBG*2400 ), STAT*2040',
#  'MUSC*2920',
#  'MATH*3200',
#  '3.00 credits in Music, including (1 of MUSC*3730, MUSC*3740, MUSC*3800, MUSC*3820, MUSC*3860, MUSC*3880)',
#  '1 of BIOM*3200, HK*3810, ZOO*3600',
#  'CIS*1910, CIS*2500',
#  'NEUR*4401',
#  'One of CLAS*1000, CLAS*2000, SXGN*1000',
#  '15.00 credits including ACCT*3280, ACCT*3340, ACCT*3350',
#  '7.50 credits including (1.00 credit in IDEV courses at the 2000 level or ONEH*2000)',
#  '1 of GEOG*2230, IDEV*2000, IDEV*2500, POLS*2080, POLS*2100, POLS*2200',
#  'ENGG*2340, MATH*2270',
#  'FRHD*4810',
#  'THST*2050, THST*2270',
#  '13.50 credits',
#  '1 of CIS*3750, CIS*3760, ENGG*4450',
#  '15.00 credits including MCS*3500',
#  'MUSC*2430',
#  'MUSC*1170',
#  'MUSC*2570',
#  '1 of POLS*2650, POLS*3180, SOAN*2120',
#  'Completion of 7.50 credits including (1 of GEOG*2460, STAT*2040 , STAT*2060, STAT*2080)',
#  '15.00 credits including ECON*2310',
#  'CIS*3110, CIS*3120',
#  'ECON*1100 (ECON*1050 or FARE*1040)',
#  'ENGG*3640',
#  'FREN*1300 or FREN*2030',
#  'ZOO*2090',
#  '1 of BIOL*1070, BIOL*1080, BIOL*1090',
#  'GEOG*1200 or GEOG*1220',
#  '1.50 credits in Classical Studies at the 3000 level',
#  'ENGG*1410',
#  '4.00 credits including (1 of BIOL*1070, BIOL*1080, BIOL*1090, CHEM*1040)',
#  '1 of BUS*2090, BUS*2220, HROB*2090',
#  '(4U mathematics or equivalent) or 0.50 credit in mathematics',
#  'ASCI*2050',
#  '10.00 credits.',
#  '14.00 credits including 1.50 credits at the 3000 level or higher in Food Science.',
#  'MATH*1160, (CHEM*3860 or PHYS*3230)',
#  '0.50 credits at the 1000 level in Geography',
#  'A minimum of 0.50 credits at the 4000-level in Studio Arts, a minimum cumulative average of at least 80% in SART courses and ARTH courses, 6.50 credits in SART and ARTH.',
#  'CHEM*1050, [IPS*1510 or ( MATH*1210, PHYS*1010)]',
#  'ENGG*3390',
#  'LARC*3430',
#  'MATH*2270, (ENGG*1500 or MATH*1160)',
#  '1 of 4U Advanced Functions, 4U Advanced Functions and Calculus or equivalent',
#  'CHEM*1050, (1 of IPS*1510, MATH*1090, MATH*1210, MATH*2080)',
#  'FOOD*2400',
#  '1 of IDEV*2000, POLS*2080, POLS*2100',
#  'PHYS*2180 or (NANO*2100, PHYS*2310)',
#  'ENGG*2230, ENGG*3650',
#  '1 of BIOL*1050, BIOL*1070, ENVM*1000, ENVM*1200, ENVS*1030',
#  '12.50 credits including ANTH*3690, SOAN*3070',
#  '1 of ECON*2740, PSYC*1010, STAT*2040, STAT*2050, STAT*2060, STAT*2080',
#  '10.00 credits including [1 of (ECON*2560 or FIN*2000), ECON*3560, FARE*2410, MGMT*3320]',
#  '4.00 credits',
#  '(MCB*2050 or MCB*2210), (1 of ANSC*3080, BIOM*3200, HK*3810, HK*3940)',
#  '5.0 credits',
#  'MBG*3060',
#  '9.00 credits including REAL*1820, REAL*2820',
#  '4U Advanced Functions',
#  'EQN*1010',
#  '3.00 credits in Theatre Studies including one of the following, as appropriate to the topic of the course: THST*2080, THST*2120, THST*2230, THST*2240.',
#  '(1 of BUS*2090, HROB*2090, HROB*2100, ACCT*2230)',
#  '(1 of CIS*1300, CIS*1500, ENGG*1410), (MATH*1080 or MATH*1200)',
#  '8.00 credits',
#  '19.75 credits towards the BENG ESC major, all 1000 and 2000 level core courses, ENGG*4000',
#  'FRHD*3200',
#  'MUSC*1410',
#  'ENGG*2010',
#  '15.00 credits including MCS*3030, MCS*3500, MCS*3620',
#  '1 of ENVS*3050, ENVS*3130, ENVS*3340, PHYS*3100',
#  'CIS*4900',
#  '1 of CLAS*3060, CLAS*3120, CLAS*3300',
#  'GEOG*3210, INDG*1000, POLS*3340, SOC*2280',
#  '5.00 credits including CHEM*1040',
#  '1 of ECON*1050, FARE*1040, FARE*1400',
#  'MICR*3330',
#  '14.00 credits including ZOO*2090',
#  '(1 of POLS*2080, POLS*2100, POLS*2200); and at least 1.00 credits at the 3000 level in the International Relations and Global Studies stream. Streams are defined under the Political Science Major.',
#  'FOOD*3030 or FOOD*3050',
#  'ECON*2310, (ECON*2770 or MATH*1210). A grade average of 70% or more in these courses .',
#  'ZOO*2700',
#  '10.00 credits including 1.50 credits in Classics.',
#  'MUSC*3910',
#  'CHEM*3860, MATH*1160',
#  'MUSC*2180, MUSC*2660',
#  'MGMT*1000',
#  '10.00 credits including ECON*1050, (MATH*1000 or MATH*1030), MCS*2600, (1 of ECON*2740, PSYC*1010, STAT*2060)',
#  'GERM*2010 or 2.50 credits in GERM',
#  '2.00 credits or (1 of PHIL*1000, PHIL*1010, PHIL*1050)',
#  '14.00 credits including 1.00 credits in Philosophy at the 3000-level',
#  'SART*4200',
#  'MUSC*1060',
#  'BIOC*3560',
#  '(ACCT*3330 or BUS*3330), (ACCT*3340 or BUS*3340)',
#  '(CHEM*2400 or CHEM*2480)',
#  'CRWR*2400',
#  'NUTR*3330, NUTR*3390, HK*3810',
#  'BIOC*2580, [1 of BIOM*3200, HK*3810, HK*3940, (ZOO*3200, ZOO*3210), ZOO*3600]',
#  '12.00 credits including MGMT*1200',
#  '(MATH*1160 or MATH*2160), (MATH*2170 or MATH*2270), (CHEM*3860 or PHYS*3230)',
#  '15.00 credits including ZOO*2090',
#  'BIOL*3060 or BIOL*3130',
#  'ENGG*2230',
#  'IDEV*1000',
#  '3.00 credits in Psychology including PSYC*2070, PSYC*2310',
#  '10.00 credits including 1.00 credits in Art History at the 3000 level.',
#  'MUSC*1710',
#  '9.00 credits',
#  'BIOC*2580, MBG*2040',
#  '1 of PHIL*2060, PHIL*3390, 1.00 credits in Philosophy at the 3000 level.',
#  'BIOL*3670',
#  '7.50 credits, including MUSC*1340',
#  '12.50 credits including SOAN*3240, (1 of GEOG*3090, IDEV*2100, POLS*2650, POLS*3180, SOAN*2120)',
#  '7.50 credits, including THST*1040',
#  '10.00 credits including REAL*1820',
#  'CHEM*1050, [IPS*1510 or (MATH*1090 or MATH*1210), (1 of PHYS*1010, PHYS*1070, PHYS*1300)]',
#  'A minimum grade of 70% in MUSC*4460',
#  '15.00 Credits including MCS*2600, MCS*3030',
#  'BIOM*3090, (NEUR*2000 or PSYC*2410)',
#  '12.50 credits including (1 of IDEV*2100, SOAN*2120, SOAN*3070), (1 of ANTH*2160, ANTH*2180, IDEV*2300, SOAN*2112)',
#  'BIOL*2400, (STAT*2040 or STAT*2230)',
#  'ENVS*1050 or ENVS*2240',
#  'MATH*2270, (CHEM*2820 or PHYS*2240)',
#  '1.00 credits in physics (excluding PHYS*1020, PHYS*1600, PHYS*1810)',
#  '(FARE*2700, or ECON*2310) 0.50 credits at the 3000 or 4000 level in FARE or ECON',
#  'SART*4410',
#  'BIOL*1070, BIOL*1090, CHEM*1050, MATH*1080',
#  '(AGR*1110 or AGR*2150), (BIOL*1050 or BIOL*1070)',
#  'ECON*1100, (ECON*1050, or FARE*1040), (1 of MATH*1030, MATH*1080, MATH*1200)',
#  'TOX*2000',
#  'MBG*2400, 0.50 credits in statistics.',
#  '13 credits including (1 of FRHD*2040, FRHD*2300, FRHD*2350, FRHD*2400, POLS*2230)',
#  '19.75 credits towards the BENG WRE major, all 1000 and 2000 level core courses, ENGG*4000.',
#  'BIOL*3450, ZOO*2700',
#  '10.00 credits including 1.50 credits in German.',
#  '(1 of MATH*1160, MATH*2150, MATH*2160), (MATH*2170 or MATH*2270), [(PHYS*2450, PHYS*2470) or (PHYS*2180 , PHYS*2310, PHYS*2340)]',
#  '7.50 credits',
#  '9.50 credits,',
#  'ANTH*1150',
#  'ECON*2310 or ECON*2200',
#  'CIS*2520, (CIS*2030 or ENGG*2410).',
#  'CIS*2500',
#  'FREN*2020, FREN*2060, FREN*2520',
#  '4U Calculus and Vectors or 4U Advanced Functions',
#  '1 of AGR*2050, AGR*2470, BOT*2100',
#  'POLS*1400 or POLS*2300',
#  'ARAB*1100',
#  'ENGG*2120',
#  'ENGG*3390 or PHYS*3130',
#  'IBIO*4500',
#  '14.00 credits, MGMT*4991',
#  '1 of POLS*2350, POLS*2250, POLS*2300',
#  '1 of STAT*2040, STAT*2060, STAT*2120, STAT*2230',
#  '(1 of POLS*2000, POLS*2100, POLS*2200), 0.50 credits at the 3000 level in the Comparative Politics stream or 0.50 credits at the 3000 level in the International Relations and Global Studies stream. Streams are defined under the Political Science Major.',
#  '7.50 credits including (1 of FREN*2060, HIST*2100, HIST*2600, POLS*2300)',
#  'Minimum of 10.00 credits. Minimum cumulative average of 70%.',
#  '2.00 credits in PHYS at the 2000 level or higher',
#  'CHIN*1280',
#  '10.00 credits, 2.00 of which must be in Political Science.',
#  '12.00 credits including ASCI*2050',
#  '7.50 credits including (1 of HIST*1150, HIST*2890, HIST*3840, POLS*3060)',
#  'PATH*3610 (or equivalent)',
#  'HIST*3560',
#  'BIOL*2060',
#  'ENVS*2230',
#  'SART*2800',
#  '15.00 credits including MCS*3030, MCS*3500',
#  '10.00 credits including BIOL*1080',
#  '12.50 credits including (IDEV*2100 or SOAN*2120), (1 of ANTH*2160, ANTH*2180, IDEV*2300, IDEV*2500, SOAN*2112, SOC*2080)',
#  '(1 of ANTH*2160, ANTH*2180, IDEV*2000, IES*2010), (1 of ANTH*2230, ANTH*2660, HIST*2090, IDEV*2400, IDEV*2500)',
#  '10.00 credits, (2 of ARTH*1520, EURO*1050, EURO*1100, EURO*1200, EURO*2200, EURO*2300, EURO*3000, EURO*3300, HIST*2510, HIST*3090, MUSC*1060, POLS*3450)',
#  'ENGG*2400',
#  '1 of SART*3600, SART*3750, (SART*2610, SART*3470)',
#  '1 of FOOD*2010, HTM*1700, HTM*2700',
#  'MATH*3100',
#  'NANO*2100',
#  '1 of NUTR*1010, NUTR*2150, NUTR*3210',
#  '0.50 credits in either Philosophy or Political Science',
#  'THST*4270',
#  '10.00 credits including 1.50 credits in Italian.',
#  'MCB*4500. Normally, students must have completed 6 semesters in an appropriate program in the biological sciences. Minimum 70% cumulative average in science courses during the first 6 semesters of the relevant majors.',
#  '10.00 credits including MCS*1000',
#  '(ECON*3600 or ECON*3810), ECON*3740, [1 of ECON*3510, ECON*3710, (ECON*3960 or FIN*3500)]',
#  'ENGG*3380 or ENGG*3640',
#  '1.50 credits in Philosophy or 7.50 credits',
#  'ACCT*3330',
#  'All Phase 3 courses',
#  '7.50 credits or 1.50 credits in Art History.',
#  'CTS*2000, CTS*2010',
#  '1 of: BIOL*2400, 1.50 credits in Philosophy, 7.50 credits',
#  'CIS*3490, (CIS*3750 or CIS*3760), (CIS*2460 or STAT*2040)',
#  '12.00 credits',
#  'ECON*2310, (ECON*2560 or FIN*2000)',
#  'BIOL*3450, (STAT*2040 or STAT*2230), (ZOO*3210 or ZOO*3610)',
#  'STAT*2050',
#  'MATH*1160, STAT*2050, (1 of IPS*1510, MATH*1090, MATH*1210, MATH*2080)',
#  'ECON*3740, (ECON*3710 or ECON*3500)',
#  '(BIOL*3130 or GEOG*3610), (1 of GEOG*2460, STAT*2040, STAT*2060, STAT*2120, STAT*2230)',
#  '10.00 credits including MCS*1000, MCS*2020',
#  '1.50 credits in biology',
#  '14.00 credits including PSYC*2310, PSYC*3290',
#  'ENGG*1210 or HK*3600',
#  'PHYS*1130, (1 of CIS*1300, CIS*1500, ENGG*1410)',
#  'GREK*1100 or 4U Greek',
#  '14.00 credits including (POLS*3650 or SOAN*3120), (SOC*2700 or SOC*3310)',
#  '14.00 credits including (POLS*3650 or SOAN*3120), (1 of ANTH*3690, SOC*2700, SOC*3310), (2 of SOC*3490, SOC*3710, SOC*3730, SOC*3740, SOC*3750)',
#  'OAGR*2070',
#  '12.50 credits including POLS*3370',
#  'NUTR*3210',
#  '15.00 credits including MCS*3030',
#  '(1 of MATH*1160, MATH*2150, MATH*2160), MATH*2200, MATH*2270, PHYS*2310, PHYS*2340',
#  '14.50 credits including CHEM*1040, (ENVS*2040 or ENVS*3210), (PBIO*3110 or PBIO*3120)',
#  '10.00 credits, including (1 of THST*2270, THST*3140, THST*3550, THST*3650, THST*3660)',
#  '7.50 credits including 0.50 credits in English (excluding ENGL*1030).',
#  'CIS*3210',
#  '13.00 credits including (1 of BIOM*2000, BIOM*3200, FRHD*2060)',
#  '(AGR*2470 or BOT*2100), (MBG*2040 or MBG*2400)',
#  '14.00 credits including (SOC*2700 or SOC*3310), (SOAN*3120 or POLS*3650 )',
#  '1 of ANSC*2340, FOOD*3090, FOOD*3140, FOOD*3160',
#  '1 of AGR*2470, BOT*2100, (AGR*2050, AGR*2150)',
#  '1 of POLS*3020, POLS*3130, POLS*3140, POLS*3350',
#  '7.50 credits including (HIST*1010 or SOC*1500)',
#  '(HK*3810 or HK*3940), NUTR*4210',
#  'MATH*1160, 1.00 credits in MATH or STAT at the 2000 level or above',
#  'ONEH*3000',
#  'POLS*2100 or POLS*2300',
#  'ENGG*1500, ENGG*2400',
#  'BIOL*3130',
#  "MBG*3350 or equivalent laboratory experience at the discretion of the student's faculty advisor. Normally, students must have completed 6 semesters in an appropriate program in the biological sciences",
#  '1 of POLS*2080, POLS*2100, POLS*2200',
#  'SART*3090 or SART*3200',
#  '9.50 credits including NUTR*2050',
#  'Completion of 4.00 credits including ENGG*1100',
#  '(1 of BIOM*3010, HK*3401, HK*3501, ZOO*2090), (1 of BIOM*3200, HK*3810, ZOO*3210, ZOO*3620)',
#  'BIOC*2580, BIOL*1080, MBG*2040',
#  '9.50 credits including (1 of ECON*1050, FARE*1040, FARE*1400), (1 of ECON*2740, STAT*2040, STAT*2060)',
#  '1 of ANTH*1150, GEOG*1220, IDEV*1000, INDG*1000, SOC*1100',
#  'ENGG*3590',
#  'FREN*4740',
#  'Completion of 6.00 credits of ENGG courses including ENGG*2100',
#  '2 of POLS*3020, POLS*3130, POLS*3140, POLS*3210, POLS*3300, POLS*3350',
#  'PSYC*4870',
#  'MICR*2420',
#  'BIOC*2580 or EQN*2040',
#  'BIOL*1080, CHEM*1040',
#  'BIOL*1070',
#  'MGMT*2500',
#  'ENGG*3070, ENGG*3510, MICR*1020',
#  '2.00 credits',
#  'MICR*2430, (MBG*3080 or MICR*3240)',
#  '10.00 credits including (BIOL*1030, BIOL*1040) or (BIOL*1070, BIOL*1090), CHEM*1040',
#  '10 credits',
#  'A minimum of 9.00 credits.',
#  'SOAN*2120, (1 of ANTH*2160, ANTH*2180, ANTH*2230, ANTH*2660, IDEV*2500)',
#  'LARC*2100, LARC*2240',
#  'ENGG*2400, ENGG*3640',
#  '1 of CHEM*3360, ENVS*3020, ENVS*3220, TOX*3360',
#  '6.00 ENGG credits including ENGG*3150',
#  'ECON*3740,FIN*3100, (ECON*3660 or FIN*3000)',
#  'HTM*3090',
#  '(1 of ANTH*2160, ANTH*2180, IDEV*2010, IDEV*2500, ONEH*2000, SOC*2080), (1 of GEOG*2210, SOAN*2120, SOAN*3070)',
#  '2.50 credits',
#  'MCB*2050, (MBG*3080 or MICR*3240)',
#  'CIS*2250, CIS*2500',
#  'ECON*1100, (ECON*1050, or FARE*1040), (1 of MATH*1000, MATH*1030, MATH*1050, MATH*1080, MATH*1200)',
#  'All Phase 1 courses',
#  '5 credits',
#  '15.00 credits including 2.00 in ANSC or EQN',
#  'CIS*2750, CIS*3490',
#  '1 of ECON*2100, ECON*2310, ECON*2650, FARE*2700',
#  'MUSC*1920',
#  '1.00 credits in English.',
#  '1 of IDEV*2400, POLS*2200, POLS*2350',
#  'SXGN*1000 or SXGN*1010',
#  '1 of ANTH*1150, FRHD*1010, FRHD*1100, PSYC*1000, SOC*1100',
#  '10.00 credits including 1.50 credits in History at the 3000-level',
#  '15.00 credits including ANTH*3690, (SOAN*3070 or SOAN*3120)',
#  '10.00 credits including MCS*1000, MCS*2600',
#  'POLS*2200, (2 of POLS*3160, POLS*3320, POLS*3490, POLS*3790)',
#  '0.50 credits in Geography',
#  '1 of ANTH*2160, ANTH*2180, GEOG*2030, IDEV*2300, IDEV*2500, SOAN*2112',
#  '14.00 credits including PSYC*2020, PSYC*3290, (1 of FRHD*2270, PSYC*2450, PSYC*2740)',
#  'BIOL*1050',
#  '7.50 credits including MUSC*2270, (MUSC*1160 or MUSC*1180)',
#  '14.00 credits, including 6 credits in Art History.',
#  'AGR*1110, CHEM*1040 (1 of BIOL*1050, BIOL*1070, BIOL*1080)',
#  'LARC*3040',
#  '9 credits',
#  'NANO*2100, (CHEM*3860 or PHYS*3230)',
#  'ENVS*1040 or GEOG*1300',
#  'LARC*3070',
#  '7.50 credits, including THST*2190',
#  'BIOC*2580',
#  '2 of BIOL*1070, BIOL*1080, BIOL*1090',
#  'LARC*2020, LARC*2420',
#  'SOAN*2111',
#  '10.00 credits, (1 of HIST*2890, HIST*3830, HIST*3840, POLS*3060)',
#  'ANSC*4700',
#  '(1 of GEOG*2460, STAT*2040, STAT*2230), (1 of BIOL*2060, ENVS*2030, GEOG*2110)',
#  '1 of FOOD*3230, POPM*3240',
#  '(1 of ANTH*2160, ANTH*2180, SOAN*2112, SOAN*2400), (POLS*2650 or SOAN*2120)',
#  'STAT*3240',
#  '(CIS*2420 or CIS*2520), ENGG*2100',
#  'GEOG*2260, (GEOG*3050 recommended)',
#  '10.00 credits including (1 of SOAN*2112, SOC*2080, SOC*2700), SOAN*2120',
#  'HK*3810 or HK*3940',
#  '10.00 credits including 1.50 credits in Spanish.',
#  'BIOC*2580, (1 of ANSC*3080, BIOM*3200, HK*3810, HK*3940, ZOO*3200, ZOO*3600)',
#  '7.50 credits including (1 of HIST*1150, HIST*2240, HIST*2890, HIST*2910, HIST*2930)',
#  '1 of FRHD*2040, FRHD*2300, FRHD*2400',
#  'FARE*3310, FARE*4370',
#  '9.00 credits including (MGMT*1000 or MGMT*2150)',
#  'BIOC*3560 (may be taken concurrently), BIOC*3570',
#  'ENGG*3150 or HK*2270',
#  'MICR*3330, (MICR*2430 )',
#  'FOOD*3140 or FOOD*3160',
#  'MUSC*1160 or MUSC*1180',
#  'MUSC*2500, (2 of MUSC*2530, MUSC*2540, MUSC*2550, MUSC*2560)',
#  'SART*3800 and 3.50 credits in Studio Art',
#  'ENGG*2230, ENGG*3260, MATH*2270',
#  '10.00 credits including CTS*2000, CTS*2010',
#  'NANO*4910',
#  '1 of IPS*1500, MATH*1080, MATH*1200, PHYS*1070, PHYS*1080, PHYS*1130, PHYS*1300',
#  'FRHD*3400, NUTR*3090, NUTR*4070',
#  'CHEM*2070',
#  '1 of SART*3770, SART*4660, SART*4670',
#  '1 of POLS*3020, POLS*3130, POLS*3350',
#  'FARE*3310, FOOD*3170',
#  '1 of SPAN*2990, SPAN*3220, SPAN*3230',
#  '7.50 credits or 1.50 credits in Art History, including ARTH*2480.',
#  'SART*2610',
#  '1 of AGR*1350, AGR*2350, EQN*1010',
#  'A minimum grade of 70% in MUSC*3410.',
#  'STAT*3100',
#  '10.00 credits including at least 1.50 credits in biology.',
#  'MATH*1160, STAT*3110, STAT*3240',
#  'ENGG*2340, ENGG*2450',
#  'BIOL*2400',
#  'EQN*2040',
#  'GEOG*3480',
#  '9.00 credits including (HTM*2010 or MCS*2000), (HTM*1160 or HTM*2100)',
#  'ENGL*2080',
#  '(CIS*2500 or ENGG*1420), (1 of CIS*1910, ENGG*1500, MATH*2000)',
#  'ITAL*2090',
#  'PSYC*2070, PSYC*2360, (2 of PSYC*2020, PSYC*2310, PSYC*2450, PSYC*2740), (1 of PSYC*2330, PSYC*2390, PSYC*2410, PSYC*2650)',
#  '(HISP*4410 or SPAN*4410), (HISP*4420 or SPAN*4420)',
#  'CHIN*1210',
#  'MGMT*1000 or MGMT*2150',
#  '2.50 credits in Psychology or 3.00 credits in Philosophy',
#  'FRHD*3290',
#  'IBIO*4521',
#  'IDEV*4100',
#  '(1 of BIOL*2060, BOT*2100, ENVM*1200, ENVS*2040 , ENVS*2330, PBIO*3110), CHEM*1040',
#  'MBG*2040, BIOL*2400 .',
#  'POLS*2000 and at least 1.00 credits at the 3000 level in the Political Thought stream. Streams are defined under the Political Science Major.',
#  'ECON*1100, (1 of IPS*1500, MATH*1030, MATH*1080, MATH*1200)',
#  '(1 of AGR*2470, BOT*2100, ENVS*2330, LARC*2240)',
#  '10.00 credits including 1.00 credits in Theatre Studies.',
#  'MATH*2130, STAT*2050, STAT*3110',
#  'ENGG*2560, ENGG*3260',
#  'CIS*1250, CIS*1300',
#  '1 of ECON*2740, PSYC*1010, STAT*2060',
#  '12.50 credits including POLS*3300',
#  '14.00 credits including [(PSYC*2040 or PSYC*3290) ), 1.00 credits in Psychology at the 3000 level]',
#  'MUSC*1180',
#  '(1 of MATH*1160, MATH*2150, MATH*2160), (MATH*2170 or MATH*2270), (PHYS*2340 or PHYS*2470)',
#  '1 of SART*3470, SART*3660, (SART*2460, SART*3600)',
#  'SART*3480',
#  'ENGG*2410, ENGG*3380',
#  '1 of IDEV*2000, IDEV*2400, POLS*2080',
#  '1 of IPS*1510, MATH*1090, MATH*1210, MATH*2080',
#  '(2 of BIOL*1050, BIOL*1070, BIOL*1080, BIOL*1090)',
#  'ENVS*4001',
#  '2.00 credits, including 0.50 credits in History at the 1000 level',
#  'LARC*3050',
#  'PHYS*4001',
#  '12.50 credits including (ANTH*3690 or SOC*3310), SOAN*3070',
#  'HK*4511',
#  'PSYC*3290',
#  'BIOC*2580, CHEM*1050, ENGG*2010',
#  'ENGG*1210, MATH*1210',
#  '1 of ANTH*1150, FRHD*1010, FRHD*1100, PSYC*1000, PSYC*1100, PSYC*1200, SOC*1100',
#  'CHEM*1050, (1 of IPS*1500, MATH*1080, MATH*1200 ), (1 of BIOL*1040, BIOL*1070, BIOL*1080, BIOL*1090)',
#  '12.50 credits including (1 of ANTH*3690, SOC*2700, SOC*3310), (1 of POLS*2650, POLS*3180, SOAN*2120)',
#  'BIOC*2580, MICR*2420, (FOOD*2150 or FOOD*3090)',
#  '2.50 credits in Psychology including PSYC*2360',
#  '1 of FRHD*2270, PSYC*1000, PSYC*1100, PSYC*1200',
#  '7.50 credits, minimum cumulative average of 60%',
#  '10.00 credits including (ANTH*2160, ANTH*2180), SOAN*2120',
#  'FARE*3310 or HTM*3120',
#  '4.00 credits including BIOL*1090',
#  '10.00 credits including HIST*2910.',
#  '14.00 credits including PSYC*3290',
#  'ECON*2310, ECON*2770, ECON*3740',
#  'BIOC*3560, MBG*2040, MICR*2420',
#  '(1 of ARTH*1220, ARTH*1510, ARTH*1520), SART*1050, SART*1060',
#  '14.00 credits including PSYC*3290, (PSYC*3000 or 7.50 credits in Psychology)',
#  '7.50 credits including MUSC*2660, (MUSC*1170 or MUSC*2180)',
#  '10.00 credits including MCS*3030',
#  'HTM*3060',
#  '1 of (ANTH*2230, GEOG*2210, SOC*2280)',
#  'NUTR*3210, (1 of BIOM*3200, HK*3810, ZOO*3210, ZOO*3620)',
#  'LARC*3060',
#  'CHEM*1040, PHYS*1130',
#  '14.00 credits including (4 of ANTH*3770, FRHD*3090, GEOG*3020, IDEV*2200, IDEV*2400, IDEV*3000, IDEV*3100, IDEV*3300, IDEV*3400, ONEH*3000, POLS*3670)',
#  'ENGG*2230, ENGG*3370',
#  '10.00 credits including (1 of HIST*2000, HIST*2200, HIST*3020)',
#  'CHEM*2700',
#  '15.00 credits',
#  'IDEV*4190',
#  'ENGL*2080, (ENGL*2120 or ENGL*2130), (ENGL*3940 or ENGL*3960)',
#  'ENVS*2400 or ENVS*3180',
#  '(BIOL*1070, BIOL*1090), (1 of BIOL*1080, BIOM*3200, HK*3810, HK*3940), (1 of BIOM*3010, HK*3401, HK*3501, ZOO*2090)',
#  '19.75 credits towards the BENG BIOE major, all 1000 and 2000 level core courses, ENGG*4000.',
#  '1 of GEOG*2030, GEOG*2210, SOC*2280',
#  '2 of BIOL*1050, BIOL*1070, BIOL*1080, BIOL*1090',
#  'ENGG*2400, MATH*2270',
#  '14.50 credits including MGMT*2260',
#  'AGR*2470',
#  '10.00 credits, including GEOG*2480',
#  '9.00 credits including MCS*1000, (HTM*2010 or MCS*2000)',
#  '1 of AGR*2320, ENVS*2060, SOIL*2010',
#  '4.00 credits.',
#  'CIS*3490',
#  'MATH*2270, (1 of IPS*1500, PHYS*1000, PHYS*1080)',
#  '(1 of IDEV*2000, POLS*2080 or POLS*2100), 1.00 credits in the Comparative Politics stream. Streams are defined under the Political Science Major.',
#  '12.50 credits including (1 of ANTH*2660, IDEV*2400, IDEV*2500, GEOG*2210, SOAN*2290), (1 of GEOG*2260, IDEV*2100, IES*2010, SOAN*3070)',
#  'BIOL*3010, BIOL*3060, (STAT*2040 or STAT*2230)',
#  'ONEH*2000 or SOAN*2120',
#  '(CIS*1300 or ENGG*1410), (CIS*1910 or ENGG*1500)',
#  '10.00 credits including HIST*2000 or HIST*2200',
#  '1 of 4U Calculus and Vectors, 4U Advanced Functions and Calculus or Grade 12 Calculus',
#  '1 of ANTH*1150, IDEV*1000, GEOG*1220, SOC*1100',
#  'ANTH*4900',
#  'BIOC*2580, (CHEM*2400 or CHEM*2480)',
#  'SART*4300',
#  '1 of AGR*2470, LARC*2240, 0.50 credits in botany',
#  'ENGG*2450, PHYS*1010',
#  '7.50 credits including [0.50 credits in English (excluding ENGL*1030) or 0.50 credits in Theatre Studies]',
#  'ENGL*1080',
#  'GEOG*3110 or GEOG*3610',
#  'Completion of previous co-op work requirements in COOP*1000',
#  '12U German or GERM*1110',
#  '12.50 credits including (1 of BUS*3000, HROB*2100, HROB*2290, HROB*3000, PSYC*3070)',
#  'SOAN*2112 or POLS*2000',
#  '(1 of MCS*1000, MGMT*1000, MGMT*2150), 10.00 credits, minimum 70% cumulative average',
#  'AGR*2050 or AGR*2470',
#  '14.00 credits, including 1.50 credits in Music at the 3000 level',
#  'MUSC*2510 on piano.',
#  '1 of BIOL*1050, BIOL*1070, BIOL*1090',
#  '14.00 credits including PSYC*3290, (1 of PSYC*2070, PSYC*3070, PSYC*3080, PSYC*3490)',
#  'THST*1200',
#  '2.50 credits in Psychology',
#  'PSYC*1500 or 4.00 credits in Psychology',
#  'ANSC*1210 or ANSC*2210',
#  'PHYS*2330',
#  'Completion of previous co-op work requirements in COOP*4000',
#  '1 of ENGL*2920, ENGL*2940, ENGL*3050, ENGL*3060, ENGL*3070, ENGL*3090',
#  'CRWR*2200 or (ENGL*1080, ENGL*2920)',
#  'CHEM*2070, (MATH*2170 or MATH*2270)',
#  'ECON*2310, ECON*2410, (ECON*2560 or FIN*2000)',
#  'ANTH*1150 or SOC*1100',
#  'SART*4700',
#  'PHYS*1010',
#  '1 of ENVM*1000, ENVM*1200, ENVS*1030',
#  'CRWR*3300',
#  '1 of BUS*3000, HROB*2100, HROB*2290, HROB*3000, PSYC*3070',
#  'HROB*2290, MGMT*1200',
#  'ENGG*3410',
#  '1 of POLS*2080, POLS*2100, POLS*2230',
#  '15.00 credits including BIOL*4150',
#  '1 of ANTH*2160, ANTH*2180, IDEV*2010, IDEV*2500, SOC*2080',
#  '[BIOL*1040 or (2 of BIOL*1050, BIOL*1070, BIOL*1080, BIOL*1090)], CHEM*1040',
#  'ENVS*4410. Minimum cumulative average of 70%.',
#  'BIOL*1070 or MICR*2420',
#  'ENGG*2120, ENGG*2230',
#  'ACCT*2230 or HTM*3070',
#  'CHEM*3430 or TOX*3300',
#  '14.00 credits including 1.50 credits in Psychology at the 3000 level',
#  'Grade 12 Latin or LAT*1110',
#  'CHEM*3430',
#  'ENGG*2100, ENGG*3240',
#  '15.00 credits including ANSC*3080, (ANSC*1210 or ANSC*2210)',
#  'ENGG*2410',
#  '14.00 credits including IDEV*2400, IDEV*3000, IDEV*3100, IDEV*3300',
#  'THST*3190',
#  'LARC*1100',
#  "MBG*3350 or equivalent laboratory experience at the discretion of the student's faculty advisor. Normally, students must have a minimum of 3.00 credits in 3000 or 4000 level BIOC, MBG, MCB OR MICR courses",
#  'ACCT*3280 or BUS*3280',
#  'FARE*3310',
#  'BIOL*1090, PSYC*1000',
#  'NANO*2000',
#  'ENGG*3490',
#  '1 of ENGG*3020, ENGG*3430, FOOD*3170',
#  'BIOC*2580, CHEM*2700',
#  'POLS*2250, and 1.00 credits at the 3000 level in the Public Policy, Governance and Law stream or the Canadian Politics stream. Streams are defined under the Political Science Major.',
#  '10.00 credits including (1 of AGR*2320, ENVS*2060, ENVS*2310, ENVS*2340)',
#  'SOAN*2112, SOAN*2120',
#  '14.00 credits and a minimum of 700 hours of verified work experience in the hospitality, sport and tourism industries.',
#  'HORT*2450',
#  '5.00 credits',
#  '1 of PHIL*2060, POLS*2000, POLS*2150, SOAN*2400',
#  'AGR*2350 or ZOO*2090',
#  '4.00 credits including BIOL*1090, PHYS*1080',
#  'NUTR*1010',
#  'NUTR*4010, NUTR*4040',
#  '(ENGG*2230 or FOOD*2620), (1 of ENGG*3020, ENGG*3430, FOOD*3170)',
#  '9.00 credits including (1 of BUS*3000, HROB*2100, HROB*2290, HROB*3000, PSYC*3070)',
#  'THST*1270',
#  'AGR*2470 or BOT*2100',
#  '12.50 credits including 5.00 credits in Political Science',
#  'POLS*2300 or POLS*2350',
#  '7.50 credits including (1 of BIOL*1070, BIOL*1080, BIOL*1090)',
#  '1 of AGR*2301/2, AGR*2320, ENVS*2060, SOIL*2010',
#  '1 of IDEV*1000, IDEV*2200, JLS*1000',
#  '1 of POLS*2350, POLS*3130, POLS*3300',
#  'GEOG*2260, GEOG*3320',
#  'MUSC*1340',
#  'A minimum of 14.00 credits.',
#  '(1 of ARTH*1220, ARTH*1510, ARTH*1520, ARTH*2220), SART*1050, SART*1060',
#  'PHYS*3510',
#  '9.00 credits including ECON*1050, ECON*1100',
#  'UNIV*2250',
#  'FRHD*3070, NUTR*2050, NUTR*3090',
#  '4.00 credits including 1 of EURO*1050, POLS*2100, POLS*2200',
#  '0.50 credits in biochemistry, (CHEM*3860 or PHYS*3230)',
#  'SOC*1100',
#  '3.00 credits in music courses including a minimum grade of 70% in MUSC*2510',
#  'FRHD*3070, NUTR*3090, NUTR*4010',
#  'BIOL*1040 or [BIOL*1090, (1 of BIOL*1050, BIOL*1070, BIOL*1080)]',
#  'HISP*2010 or SPAN*2010',
#  '12.50 credits including EQN*2200',
#  'ONEH*1000',
#  'GEOG*3000',
#  '1 of ENGG*1100, ENVS*1050, ENVS*1060, GEOG*1300, GEOG*1350, GEOL*1050, GEOL*1100',
#  '14.00 credits',
#  'BIOL*2060 or ENVS*2330',
#  '1 of FRHD*2270, PSYC*2310, PSYC*2740, PSYC*2450',
#  'BIOL*1070, CHEM*1050, ZOO*2700 ',
#  'MCB*2050',
#  '14.50 credits including ECON*2310, ECON*2770',
#  'CHIN*2200',
#  '14.00 credits including (1 of HTM*1000, HTM*1160, HTM*2020)',
#  'CIS*2750, CIS*3260',
#  '(SOAN*2112 or SOC*2700), SOAN*2120',
#  '[CIS*1910 or (CIS*2910 and ENGG*1500)], CIS*2520',
#  'REAL*1820, (ECON*2740 or STAT*2060)',
#  'IPS*1500',
#  '4.00 credits in music courses including a minimum grade of 70% in MUSC*3500',
#  '(ECON*1050 or FARE*1040), (1 of IPS*1500, MATH*1030, MATH*1080, MATH*1200)',
#  'BIOL*1090, EQN*2040',
#  'HTM*2030, HTM*2700',
#  '10.00 credits including (1 of HIST*2340, HIST*2960, HIST*3410, HIST*3910)',
#  '7.50 credits including MUSC*2100, MUSC*2220',
#  '2.00 credits in Psychology including (FRHD*2270 or PSYC*2450)',
#  'BIOC*3560 or BIOC*3570',
#  '(FOOD*2010 or FOOD*2150), (1 of FOOD*2410, FOOD*3140, FOOD*3160), (1 of FOOD*2420, FOOD*3230, FOOD*3240 )',
#  '14.00 credits including (1 of NEUR*3500, PSYC*3000, 7.50 credits in Psychology)',
#  'ITAL*1060',
#  '2.00 credits or (ARTH*1510 or ARTH*1520)',
#  '2.50 credits in Psychology or PSYC*2310',
#  'STAT*2120',
#  '1.00 credits in Statistics at the 3000 level or above.',
#  '1 of SART*4660, SART*4670, SART*4810',
#  '1 of BIOM*3200, HK*3810, HK*3940, NEUR*2000, PHYS*2030, PSYC*2410, ZOO*3200, ZOO*3600',
#  'MCB*2050, (NEUR*2000 or PSYC*2410),',
#  'LARC*3060, LARC*3440, LARC*4610',
#  '1 of AGR*2050, AGR*2320, AGR*2470, ENVS*2060',
#  'At least 3.0 mathematics and/or statistics credits at the 3000 level or above.',
#  'MATH*1200, PHYS*1130',
#  'ENVS*3050',
#  'HIST*3480',
#  'Admission to the Latin America semester',
#  'POLS*2250 and 1.00 credits at the 3000 level in the Public Policy, Governance and Law stream or the Canadian Politics stream. Streams are defined under the Political Science Major.',
#  'ZOO*3610',
#  'SPAN*1100',
#  'ECON*2310, ECON*2410, ECON*2740, ECON*2770',
#  'ACCT*1220 or ACCT*2220',
#  'IES*2010, 12.50 credits',
#  'CIS*2500 or work experience in a related field.',
#  '13.00 credits and a minimum cumulative average of 70%.',
#  'ENGG*2160, MATH*2130, MATH*2270',
#  'SOAN*2120',
#  'A minimum of 14.00 credits including 2.50 credits in Art History.',
#  '1 of CRWR*2100, CRWR*2150, (ENGL*1080, ENGL*2920)',
#  'HISP*3500 or SPAN*3500',
#  'SART*4750',
#  ...}

# %%
# Tokenizer

class TokenType(Enum):
    N_OF = 1
    COURSE = 2
    AND = 3
    OR = 4
    OPEN_PAREN = 5
    CLOSE_PAREN = 6
    UNKNOWN = 7

class Token:
    def __init__(self, type: TokenType, value: int | str | None=None):
        self.type = type
        self.value = value
    
    def __repr__(self):
        if self.type == TokenType.UNKNOWN:
            return str(self.value)

        return f"-{self.type.name}({self.value | ''})-"

class Tokenizer:
    def __init__(self, text: str):
        self.text = text
        self.index = 0

        self.tokens = self.tokenize()

    def tokenize(self) -> list[Token]:
        tokens: Token = []

        while self.index < len(self.text):
            buffer = self._peak()

            # Parentheses
            if buffer == "[":
                tokens.append(Token(TokenType.OPEN_PAREN))
                self._next()
                continue
            if buffer == "]":
                tokens.append(Token(TokenType.CLOSE_PAREN))
                self._next()
                continue
            if buffer == "(":
                tokens.append(Token(TokenType.OPEN_PAREN))
                self._next()
                continue
            if buffer == ")":
                tokens.append(Token(TokenType.CLOSE_PAREN))
                self._next()
                continue

            # n of
            if buffer.isdigit():
                buffer += self._peak(1, 3)
                if re.match(r"[0-9] of", buffer):
                    tokens.append(Token(TokenType.N_OF, int(buffer[0])))
                    self._next(len(buffer))
                    continue

            # Default
            tokens.append(Token(TokenType.UNKNOWN, buffer))
            self._next(len(buffer))
    
        return tokens


    def _peak(self, n=0, length=1):
        return self.text[self.index + n: self.index + n + length + 1]
    
    def _next(self, n=1):
        self.index += n

# %%
for text in parsed[1]:
    print(Tokenizer(text).tokens)
    break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Moulik\Programming\Guelph Course Scraper\main.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/e%3A/Moulik/Programming/Guelph%20Course%20Scraper/main.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> for text in parsed[1]:
# ----> <a href='vscode-notebook-cell:/e%3A/Moulik/Programming/Guelph%20Course%20Scraper/main.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a>     print(Tokenizer(text).tokens)
#       <a href='vscode-notebook-cell:/e%3A/Moulik/Programming/Guelph%20Course%20Scraper/main.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a>     break
#
# File ~\AppData\Roaming\Python\Python312\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py:1197, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#    1195 if is_line:
#    1196     self.set_suspend(thread, step_cmd, original_step_cmd=info.pydev_original_step_cmd)
# -> 1197     self.do_wait_suspend(thread, frame, event, arg)
#    1198 elif is_return:  # return event
#    1199     back = frame.f_back
#
# File ~\AppData\Roaming\Python\Python312\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py:165, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     164 def do_wait_suspend(self, *args, **kwargs):
# --> 165     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\debugpy\_vendored\pydevd\pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Roaming\Python\Python312\site-packages\debugpy\_vendored\pydevd\pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:
